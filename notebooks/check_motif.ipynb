# %%
import os, sys, shutil
import pathlib
import glob as glob
import numpy as np
import re
import warnings
from pdbfixer import PDBFixer
from openmm.app import PDBxFile, PDBFile
import mdtraj as md

# %%
#warnings.filterwarnings("ignore")

# %%
def check_file(file):
    """
    """    
    basename = os.path.basename(file)
    #print(">{}".format(basename))

    with warnings.catch_warnings(record=True) as w:
        warnings.simplefilter("default")
        fixer = PDBFixer(filename=file)
    fixer.findMissingResidues()
    fixer.findMissingAtoms()

    
    n_atoms = 0
    n_residues = 0
    with open(file, "r") as rf:
        for l in rf.readlines():
            _l = l.strip('\n').split()
            if l.startswith("ATOM"):
                n_atoms += 1
                symbol = _l[2]
                if symbol == "P":
                    n_residues += 1


    if fixer.topology.getNumResidues() != n_residues:
        print("{}: Perhaps same residue ID? Number of residues does not match (residues: {}->{} / atoms: {}->{})".format(basename, \
                                                                                                                         n_residues, fixer.topology.getNumResidues(), \
                                                                                                                         n_atoms, fixer.topology.getNumAtoms()))
        print("-----------------------------\n")
        
        shutil.move(file, file + ".warning")
    elif fixer.missingAtoms:
        print("{}: add missing atoms. check manually".format(basename))
        print(fixer.missingAtoms)
        print("-----------------------------\n")
        fixer.addMissingAtoms()
        shutil.move(file, file + ".missing_atoms")
        PDBxFile.writeFile(fixer.topology, fixer.positions, open(file + ".missing_atoms_added", "w"))

# %%
if __name__ == "__main__":
    base_path = os.path.dirname(os.path.abspath("__file__")).strip('notebooks')
    
    files_for_hairpins = glob.glob(os.path.join(base_path) + "data/HairpinLoopMotifAtlasRelease3.61/*.cif")
    files_for_internals = glob.glob(os.path.join(base_path) + "data/InternalLoopMotifAtlasRelease3.61/*.cif")
    files_for_junctions = glob.glob(os.path.join(base_path) + "data/nrlist_3.245_4.0A/JunctionLoop/*.cif")    
    files = files_for_hairpins + files_for_internals + files_for_junctions
    
    for file in files:
        check_file(file)
# Out:
# HL_44730.2.cif: Perhaps same residue ID? Number of residues does not match (residues: 6->3 / atoms: 126->26)
# -----------------------------
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# HL_51090.1.cif: add missing atoms. check manually
# {<Residue 9 (A) of chain 0>: [<Atom 0 (P) of chain 0 residue 0 (A)>, <Atom 1 (OP1) of chain 0 residue 0 (A)>, <Atom 2 (OP2) of chain 0 residue 0 (A)>, <Atom 3 (O5') of chain 0 residue 0 (A)>, <Atom 4 (C5') of chain 0 residue 0 (A)>, <Atom 5 (C4') of chain 0 residue 0 (A)>, <Atom 6 (O4') of chain 0 residue 0 (A)>, <Atom 7 (C3') of chain 0 residue 0 (A)>, <Atom 8 (O3') of chain 0 residue 0 (A)>, <Atom 9 (C2') of chain 0 residue 0 (A)>, <Atom 10 (O2') of chain 0 residue 0 (A)>, <Atom 11 (C1') of chain 0 residue 0 (A)>, <Atom 15 (C5) of chain 0 residue 0 (A)>, <Atom 16 (C6) of chain 0 residue 0 (A)>, <Atom 18 (N1) of chain 0 residue 0 (A)>, <Atom 19 (C2) of chain 0 residue 0 (A)>, <Atom 20 (N3) of chain 0 residue 0 (A)>, <Atom 21 (C4) of chain 0 residue 0 (A)>]}
# -----------------------------
#
# HL_01181.4.cif: Perhaps same residue ID? Number of residues does not match (residues: 7->8 / atoms: 162->162)
# -----------------------------
#
# HL_70505.1.cif: add missing atoms. check manually
# {<Residue 6 (C) of chain 0>: [<Atom 0 (P) of chain 0 residue 0 (C)>, <Atom 1 (OP1) of chain 0 residue 0 (C)>, <Atom 2 (OP2) of chain 0 residue 0 (C)>, <Atom 3 (O5') of chain 0 residue 0 (C)>, <Atom 4 (C5') of chain 0 residue 0 (C)>, <Atom 5 (C4') of chain 0 residue 0 (C)>, <Atom 6 (O4') of chain 0 residue 0 (C)>, <Atom 7 (C3') of chain 0 residue 0 (C)>, <Atom 8 (O3') of chain 0 residue 0 (C)>, <Atom 9 (C2') of chain 0 residue 0 (C)>, <Atom 10 (O2') of chain 0 residue 0 (C)>, <Atom 11 (C1') of chain 0 residue 0 (C)>, <Atom 12 (N1) of chain 0 residue 0 (C)>, <Atom 13 (C2) of chain 0 residue 0 (C)>, <Atom 15 (N3) of chain 0 residue 0 (C)>, <Atom 16 (C4) of chain 0 residue 0 (C)>, <Atom 18 (C5) of chain 0 residue 0 (C)>, <Atom 19 (C6) of chain 0 residue 0 (C)>]}
# -----------------------------
#
# HL_35188.1.cif: add missing atoms. check manually
# {<Residue 5 (U) of chain 0>: [<Atom 0 (P) of chain 0 residue 0 (U)>, <Atom 1 (OP1) of chain 0 residue 0 (U)>, <Atom 2 (OP2) of chain 0 residue 0 (U)>, <Atom 3 (O5') of chain 0 residue 0 (U)>, <Atom 4 (C5') of chain 0 residue 0 (U)>, <Atom 5 (C4') of chain 0 residue 0 (U)>, <Atom 6 (O4') of chain 0 residue 0 (U)>, <Atom 7 (C3') of chain 0 residue 0 (U)>, <Atom 8 (O3') of chain 0 residue 0 (U)>, <Atom 9 (C2') of chain 0 residue 0 (U)>, <Atom 10 (O2') of chain 0 residue 0 (U)>, <Atom 11 (C1') of chain 0 residue 0 (U)>, <Atom 12 (N1) of chain 0 residue 0 (U)>, <Atom 13 (C2) of chain 0 residue 0 (U)>, <Atom 14 (O2) of chain 0 residue 0 (U)>, <Atom 15 (N3) of chain 0 residue 0 (U)>, <Atom 16 (C4) of chain 0 residue 0 (U)>, <Atom 18 (C5) of chain 0 residue 0 (U)>, <Atom 19 (C6) of chain 0 residue 0 (U)>]}
# -----------------------------
#
# HL_49873.1.cif: add missing atoms. check manually
# {<Residue 9 (A) of chain 0>: [<Atom 0 (P) of chain 0 residue 0 (A)>, <Atom 1 (OP1) of chain 0 residue 0 (A)>, <Atom 2 (OP2) of chain 0 residue 0 (A)>, <Atom 3 (O5') of chain 0 residue 0 (A)>, <Atom 4 (C5') of chain 0 residue 0 (A)>, <Atom 5 (C4') of chain 0 residue 0 (A)>, <Atom 6 (O4') of chain 0 residue 0 (A)>, <Atom 7 (C3') of chain 0 residue 0 (A)>, <Atom 8 (O3') of chain 0 residue 0 (A)>, <Atom 9 (C2') of chain 0 residue 0 (A)>, <Atom 10 (O2') of chain 0 residue 0 (A)>, <Atom 11 (C1') of chain 0 residue 0 (A)>, <Atom 15 (C5) of chain 0 residue 0 (A)>, <Atom 16 (C6) of chain 0 residue 0 (A)>, <Atom 18 (N1) of chain 0 residue 0 (A)>, <Atom 19 (C2) of chain 0 residue 0 (A)>, <Atom 20 (N3) of chain 0 residue 0 (A)>, <Atom 21 (C4) of chain 0 residue 0 (A)>]}
# -----------------------------
#
# HL_19239.1.cif: add missing atoms. check manually
# {<Residue 9 (A) of chain 0>: [<Atom 0 (P) of chain 0 residue 0 (A)>, <Atom 1 (OP1) of chain 0 residue 0 (A)>, <Atom 2 (OP2) of chain 0 residue 0 (A)>, <Atom 3 (O5') of chain 0 residue 0 (A)>, <Atom 4 (C5') of chain 0 residue 0 (A)>, <Atom 5 (C4') of chain 0 residue 0 (A)>, <Atom 6 (O4') of chain 0 residue 0 (A)>, <Atom 7 (C3') of chain 0 residue 0 (A)>, <Atom 8 (O3') of chain 0 residue 0 (A)>, <Atom 9 (C2') of chain 0 residue 0 (A)>, <Atom 10 (O2') of chain 0 residue 0 (A)>, <Atom 11 (C1') of chain 0 residue 0 (A)>, <Atom 15 (C5) of chain 0 residue 0 (A)>, <Atom 16 (C6) of chain 0 residue 0 (A)>, <Atom 18 (N1) of chain 0 residue 0 (A)>, <Atom 19 (C2) of chain 0 residue 0 (A)>, <Atom 20 (N3) of chain 0 residue 0 (A)>, <Atom 21 (C4) of chain 0 residue 0 (A)>]}
# -----------------------------
#
# HL_48810.1.cif: Perhaps same residue ID? Number of residues does not match (residues: 11->10 / atoms: 236->216)
# -----------------------------
#
# IL_46464.1.cif: Perhaps same residue ID? Number of residues does not match (residues: 9->8 / atoms: 194->154)
# -----------------------------
#
# IL_51971.1.cif: Perhaps same residue ID? Number of residues does not match (residues: 6->3 / atoms: 130->65)
# -----------------------------
#
# IL_16160.1.cif: Perhaps same residue ID? Number of residues does not match (residues: 6->3 / atoms: 188->94)
# -----------------------------
#
# IL_50053.1.cif: Perhaps same residue ID? Number of residues does not match (residues: 5->6 / atoms: 123->123)
# -----------------------------
#
# IL_50112.1.cif: Perhaps same residue ID? Number of residues does not match (residues: 8->4 / atoms: 166->83)
# -----------------------------
#
# IL_57188.3.cif: add missing atoms. check manually
# {<Residue 10 (A) of chain 0>: [<Atom 0 (P) of chain 0 residue 0 (A)>, <Atom 1 (OP1) of chain 0 residue 0 (A)>, <Atom 2 (OP2) of chain 0 residue 0 (A)>, <Atom 3 (O5') of chain 0 residue 0 (A)>, <Atom 4 (C5') of chain 0 residue 0 (A)>, <Atom 5 (C4') of chain 0 residue 0 (A)>, <Atom 6 (O4') of chain 0 residue 0 (A)>, <Atom 7 (C3') of chain 0 residue 0 (A)>, <Atom 8 (O3') of chain 0 residue 0 (A)>, <Atom 9 (C2') of chain 0 residue 0 (A)>, <Atom 10 (O2') of chain 0 residue 0 (A)>, <Atom 11 (C1') of chain 0 residue 0 (A)>, <Atom 15 (C5) of chain 0 residue 0 (A)>, <Atom 16 (C6) of chain 0 residue 0 (A)>, <Atom 18 (N1) of chain 0 residue 0 (A)>, <Atom 19 (C2) of chain 0 residue 0 (A)>, <Atom 20 (N3) of chain 0 residue 0 (A)>, <Atom 21 (C4) of chain 0 residue 0 (A)>]}
# -----------------------------
#
# IL_89836.1.cif: Perhaps same residue ID? Number of residues does not match (residues: 12->11 / atoms: 262->240)
# -----------------------------
#
# IL_22427.1.cif: Perhaps same residue ID? Number of residues does not match (residues: 8->4 / atoms: 166->83)
# -----------------------------
#
# IL_80617.1.cif: Perhaps same residue ID? Number of residues does not match (residues: 6->3 / atoms: 130->65)
# -----------------------------
#
# IL_77034.1.cif: add missing atoms. check manually
# {<Residue 4 (A) of chain 0>: [<Atom 0 (P) of chain 0 residue 0 (A)>, <Atom 1 (OP1) of chain 0 residue 0 (A)>, <Atom 2 (OP2) of chain 0 residue 0 (A)>, <Atom 3 (O5') of chain 0 residue 0 (A)>, <Atom 4 (C5') of chain 0 residue 0 (A)>, <Atom 5 (C4') of chain 0 residue 0 (A)>, <Atom 6 (O4') of chain 0 residue 0 (A)>, <Atom 7 (C3') of chain 0 residue 0 (A)>, <Atom 8 (O3') of chain 0 residue 0 (A)>, <Atom 9 (C2') of chain 0 residue 0 (A)>, <Atom 10 (O2') of chain 0 residue 0 (A)>, <Atom 11 (C1') of chain 0 residue 0 (A)>, <Atom 15 (C5) of chain 0 residue 0 (A)>, <Atom 16 (C6) of chain 0 residue 0 (A)>, <Atom 18 (N1) of chain 0 residue 0 (A)>, <Atom 19 (C2) of chain 0 residue 0 (A)>, <Atom 20 (N3) of chain 0 residue 0 (A)>, <Atom 21 (C4) of chain 0 residue 0 (A)>]}
# -----------------------------
#
# J3_6ZVK_022.cif: Perhaps same residue ID? Number of residues does not match (residues: 28->29 / atoms: 615->615)
# -----------------------------
#
# J3_7RQB_030.cif: Perhaps same residue ID? Number of residues does not match (residues: 15->10 / atoms: 324->137)
# -----------------------------
#
# J3_5VPP_042.cif: Perhaps same residue ID? Number of residues does not match (residues: 12->8 / atoms: 261->113)
# -----------------------------
#
# J3_2UXC_006.cif: Perhaps same residue ID? Number of residues does not match (residues: 23->22 / atoms: 499->476)
# -----------------------------
#
# J3_1N33_006.cif: Perhaps same residue ID? Number of residues does not match (residues: 20->19 / atoms: 433->410)
# -----------------------------
#
# J3_5E81_021.cif: Perhaps same residue ID? Number of residues does not match (residues: 21->20 / atoms: 456->436)
# -----------------------------
#
# J3_5IBB_015.cif: Perhaps same residue ID? Number of residues does not match (residues: 12->8 / atoms: 261->113)
# -----------------------------
#
# J3_6CZR_010.cif: add missing atoms. check manually
# {<Residue 4 (U) of chain 0>: [<Atom 3 (O5') of chain 0 residue 0 (U)>]}
# -----------------------------
#
# J3_1N32_006.cif: Perhaps same residue ID? Number of residues does not match (residues: 19->18 / atoms: 413->390)
# -----------------------------
#
# J3_6ORD_043.cif: Perhaps same residue ID? Number of residues does not match (residues: 15->11 / atoms: 324->159)
# -----------------------------
#
# J3_4GCW_002.cif: Perhaps same residue ID? Number of residues does not match (residues: 13->14 / atoms: 293->293)
# -----------------------------
#
# J3_7OIF_022.cif: add missing atoms. check manually
# {<Residue 8 (C) of chain 0>: [<Atom 5 (C4') of chain 0 residue 0 (C)>]}
# -----------------------------
#
# J3_5VPO_043.cif: Perhaps same residue ID? Number of residues does not match (residues: 12->8 / atoms: 261->113)
# -----------------------------
#
# J3_4GCW_001.cif: Perhaps same residue ID? Number of residues does not match (residues: 13->14 / atoms: 293->293)
# -----------------------------
#
# J3_5OT7_010.cif: Perhaps same residue ID? Number of residues does not match (residues: 15->10 / atoms: 324->137)
# -----------------------------
#
# J3_6GSK_040.cif: Perhaps same residue ID? Number of residues does not match (residues: 12->8 / atoms: 261->113)
# -----------------------------
#
# J3_6NTA_015.cif: Perhaps same residue ID? Number of residues does not match (residues: 15->10 / atoms: 324->116)
# -----------------------------
#
# J3_6GSL_014.cif: Perhaps same residue ID? Number of residues does not match (residues: 12->8 / atoms: 261->113)
# -----------------------------
#
# J3_4TUE_016.cif: Perhaps same residue ID? Number of residues does not match (residues: 12->8 / atoms: 261->113)
# -----------------------------
#
# J3_5IB8_015.cif: Perhaps same residue ID? Number of residues does not match (residues: 12->8 / atoms: 261->113)
# -----------------------------
#
# J3_7U2I_003.cif: Perhaps same residue ID? Number of residues does not match (residues: 15->10 / atoms: 324->137)
# -----------------------------
#
# J3_4V4J_003.cif: Perhaps same residue ID? Number of residues does not match (residues: 11->7 / atoms: 241->112)
# -----------------------------
#
# J3_4V5K_012.cif: Perhaps same residue ID? Number of residues does not match (residues: 14->9 / atoms: 304->135)
# -----------------------------
#
# J3_7ACJ_021.cif: add missing atoms. check manually
# {<Residue 8 (C) of chain 0>: [<Atom 5 (C4') of chain 0 residue 0 (C)>]}
# -----------------------------
#
# J3_2UXD_006.cif: add missing atoms. check manually
# {<Residue 5 (C) of chain 0>: [<Atom 0 (P) of chain 0 residue 0 (C)>, <Atom 1 (OP1) of chain 0 residue 0 (C)>, <Atom 2 (OP2) of chain 0 residue 0 (C)>, <Atom 3 (O5') of chain 0 residue 0 (C)>, <Atom 4 (C5') of chain 0 residue 0 (C)>, <Atom 5 (C4') of chain 0 residue 0 (C)>, <Atom 6 (O4') of chain 0 residue 0 (C)>, <Atom 7 (C3') of chain 0 residue 0 (C)>, <Atom 8 (O3') of chain 0 residue 0 (C)>, <Atom 9 (C2') of chain 0 residue 0 (C)>, <Atom 10 (O2') of chain 0 residue 0 (C)>, <Atom 11 (C1') of chain 0 residue 0 (C)>, <Atom 12 (N1) of chain 0 residue 0 (C)>, <Atom 13 (C2) of chain 0 residue 0 (C)>, <Atom 15 (N3) of chain 0 residue 0 (C)>, <Atom 16 (C4) of chain 0 residue 0 (C)>, <Atom 18 (C5) of chain 0 residue 0 (C)>, <Atom 19 (C6) of chain 0 residue 0 (C)>]}
# -----------------------------
#
# J3_4V5G_039.cif: Perhaps same residue ID? Number of residues does not match (residues: 16->15 / atoms: 346->305)
# -----------------------------
#
# J3_5VPP_015.cif: Perhaps same residue ID? Number of residues does not match (residues: 12->8 / atoms: 261->113)
# -----------------------------
#
# J3_7U2I_030.cif: Perhaps same residue ID? Number of residues does not match (residues: 15->10 / atoms: 324->137)
# -----------------------------
#
# J3_4V5K_034.cif: Perhaps same residue ID? Number of residues does not match (residues: 14->9 / atoms: 304->135)
# -----------------------------
#
# J3_7OT5_023.cif: add missing atoms. check manually
# {<Residue 8 (C) of chain 0>: [<Atom 5 (C4') of chain 0 residue 0 (C)>]}
# -----------------------------
#
# J3_6Q9A_022.cif: add missing atoms. check manually
# {<Residue 8 (C) of chain 0>: [<Atom 5 (C4') of chain 0 residue 0 (C)>]}
# -----------------------------
#
# J3_1HNW_006.cif: Perhaps same residue ID? Number of residues does not match (residues: 21->20 / atoms: 456->433)
# -----------------------------
#
# J3_6NTA_008.cif: Perhaps same residue ID? Number of residues does not match (residues: 19->16 / atoms: 413->350)
# -----------------------------
#
# J3_6GSL_034.cif: Perhaps same residue ID? Number of residues does not match (residues: 19->18 / atoms: 413->393)
# -----------------------------
#
# J3_5IBB_041.cif: Perhaps same residue ID? Number of residues does not match (residues: 12->8 / atoms: 261->113)
# -----------------------------
#
# J3_4DR7_006.cif: Perhaps same residue ID? Number of residues does not match (residues: 19->18 / atoms: 413->390)
# -----------------------------
#
# J3_4V5G_015.cif: Perhaps same residue ID? Number of residues does not match (residues: 15->10 / atoms: 324->137)
# -----------------------------
#
# J3_6ORD_015.cif: Perhaps same residue ID? Number of residues does not match (residues: 15->11 / atoms: 324->159)
# -----------------------------
#
# J3_6CFJ_031.cif: Perhaps same residue ID? Number of residues does not match (residues: 15->10 / atoms: 324->137)
# -----------------------------
#
# J3_7AC7_022.cif: add missing atoms. check manually
# {<Residue 8 (C) of chain 0>: [<Atom 5 (C4') of chain 0 residue 0 (C)>]}
# -----------------------------
#
# J3_4B3R_006.cif: add missing atoms. check manually
# {<Residue 2 (G) of chain 0>: [<Atom 0 (P) of chain 0 residue 0 (G)>, <Atom 1 (OP1) of chain 0 residue 0 (G)>, <Atom 2 (OP2) of chain 0 residue 0 (G)>, <Atom 3 (O5') of chain 0 residue 0 (G)>, <Atom 4 (C5') of chain 0 residue 0 (G)>, <Atom 5 (C4') of chain 0 residue 0 (G)>, <Atom 6 (O4') of chain 0 residue 0 (G)>, <Atom 7 (C3') of chain 0 residue 0 (G)>, <Atom 8 (O3') of chain 0 residue 0 (G)>, <Atom 9 (C2') of chain 0 residue 0 (G)>, <Atom 10 (O2') of chain 0 residue 0 (G)>, <Atom 11 (C1') of chain 0 residue 0 (G)>, <Atom 12 (N9) of chain 0 residue 0 (G)>, <Atom 13 (C8) of chain 0 residue 0 (G)>, <Atom 14 (N7) of chain 0 residue 0 (G)>, <Atom 15 (C5) of chain 0 residue 0 (G)>, <Atom 16 (C6) of chain 0 residue 0 (G)>, <Atom 18 (N1) of chain 0 residue 0 (G)>, <Atom 19 (C2) of chain 0 residue 0 (G)>, <Atom 21 (N3) of chain 0 residue 0 (G)>, <Atom 22 (C4) of chain 0 residue 0 (G)>]}
# -----------------------------
#
# J3_7NWG_002.cif: add missing atoms. check manually
# {<Residue 19 (G) of chain 0>: [<Atom 0 (P) of chain 0 residue 0 (G)>, <Atom 1 (OP1) of chain 0 residue 0 (G)>, <Atom 2 (OP2) of chain 0 residue 0 (G)>, <Atom 3 (O5') of chain 0 residue 0 (G)>, <Atom 4 (C5') of chain 0 residue 0 (G)>, <Atom 5 (C4') of chain 0 residue 0 (G)>, <Atom 6 (O4') of chain 0 residue 0 (G)>, <Atom 7 (C3') of chain 0 residue 0 (G)>, <Atom 8 (O3') of chain 0 residue 0 (G)>, <Atom 9 (C2') of chain 0 residue 0 (G)>, <Atom 10 (O2') of chain 0 residue 0 (G)>, <Atom 11 (C1') of chain 0 residue 0 (G)>, <Atom 15 (C5) of chain 0 residue 0 (G)>, <Atom 16 (C6) of chain 0 residue 0 (G)>, <Atom 18 (N1) of chain 0 residue 0 (G)>, <Atom 19 (C2) of chain 0 residue 0 (G)>, <Atom 21 (N3) of chain 0 residue 0 (G)>, <Atom 22 (C4) of chain 0 residue 0 (G)>]}
# -----------------------------
#
# J3_5VPO_016.cif: Perhaps same residue ID? Number of residues does not match (residues: 12->8 / atoms: 261->113)
# -----------------------------
#
# J3_7RQB_003.cif: Perhaps same residue ID? Number of residues does not match (residues: 15->10 / atoms: 324->137)
# -----------------------------
#
# J3_6O8W_009.cif: add missing atoms. check manually
# {<Residue 3 (G) of chain 0>: [<Atom 1 (OP1) of chain 0 residue 0 (G)>]}
# -----------------------------
#
# J3_5T7V_001.cif: Perhaps same residue ID? Number of residues does not match (residues: 18->19 / atoms: 408->408)
# -----------------------------
#
# J3_6NTA_042.cif: Perhaps same residue ID? Number of residues does not match (residues: 15->10 / atoms: 324->116)
# -----------------------------
#
# J3_6GSK_015.cif: Perhaps same residue ID? Number of residues does not match (residues: 14->8 / atoms: 304->113)
# -----------------------------
#
# J3_6GSL_041.cif: Perhaps same residue ID? Number of residues does not match (residues: 12->8 / atoms: 261->113)
# -----------------------------
#
# J3_4TUE_043.cif: Perhaps same residue ID? Number of residues does not match (residues: 12->8 / atoms: 261->113)
# -----------------------------
#
# J3_5IB8_041.cif: Perhaps same residue ID? Number of residues does not match (residues: 12->8 / atoms: 261->113)
# -----------------------------
#
# J3_6Q97_017.cif: add missing atoms. check manually
# {<Residue 8 (C) of chain 0>: [<Atom 5 (C4') of chain 0 residue 0 (C)>]}
# -----------------------------
